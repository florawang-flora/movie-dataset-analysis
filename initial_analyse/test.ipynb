# %%
# package 
import pandas as pd 
import ast

# %%
import os
print(os.getcwd())
pd.set_option('display.max_colwidth', None)
# Out:
# /Users/mac/VSstudio/movie-dataset-analysis/initial_analyse

# %% [markdown]
# # cerdit data

# %%
# create data shape 45476 rows with 3 columns.
credits = pd.read_csv('../src/credits.csv')
print(credits.shape)
print(credits.columns)
# Out:
# (45476, 3)
# Index(['cast', 'crew', 'id'], dtype='object')

# %%
#  integration
def read_csvs(data_source):
    dfs = pd.read_csv(f'../src/{data_source}.csv')
    return dfs

data_sources = ['credits','keywords', 'links_small', 'movies_metadata','ratings_small']
dfs = {}

for data_source in data_sources: 
    dfs[data_source] = read_csvs(data_source)
    
    
credits = dfs['credits']
credits.shape
# Out:
# /var/folders/rt/2qm8vc4d2z5429h4tm7j7pkr0000gn/T/ipykernel_7698/3327165739.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = pd.read_csv(f'../src/{data_source}.csv')
# (45476, 3)

# %%
credits.head(1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
# the ast.literal_eval means change the string to the python object, in this case, it will return to the list.
def parsed(x):
    if isinstance(x, str):
        return ast.literal_eval(x)
    else:
        return []

# %%
credits['cast'] = credits['cast'].apply(parsed)
credits.head(1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# It seems like the credtis table is a list of the dictionary. I want to go down then keep looking it.

# %% [markdown]
# # cast df

# %% [markdown]
# Since we finish change the column format from string to the list of dictionary. Now, we want to flatten the list of dict that for analyses

# %%
credits.head(1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
credits_df = credits[['cast', 'id']].explode('cast')
print(credits_df.head())
# Out:
#                                                                                                                                                                                                                cast  \
# 0                {'cast_id': 14, 'character': 'Woody (voice)', 'credit_id': '52fe4284c3a36847f8024f95', 'gender': 2, 'id': 31, 'name': 'Tom Hanks', 'order': 0, 'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'}
# 0    {'cast_id': 15, 'character': 'Buzz Lightyear (voice)', 'credit_id': '52fe4284c3a36847f8024f99', 'gender': 2, 'id': 12898, 'name': 'Tim Allen', 'order': 1, 'profile_path': '/uX2xVf6pMmPepxnvFWyBtjexzgY.jpg'}
# 0  {'cast_id': 16, 'character': 'Mr. Potato Head (voice)', 'credit_id': '52fe4284c3a36847f8024f9d', 'gender': 2, 'id': 7167, 'name': 'Don Rickles', 'order': 2, 'profile_path': '/h5BcaDMPRVLHLDzbQavec4xfSdt.jpg'}
# ...

# %%
# flattern the cast column.
credits_sub_df = pd.json_normalize(credits_df['cast'])
credits_sub_df.head()
# Out:
#    cast_id                character                 credit_id  gender  \
# 0     14.0            Woody (voice)  52fe4284c3a36847f8024f95     2.0
# 1     15.0   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99     2.0
# 2     16.0  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d     2.0
# 3     17.0       Slinky Dog (voice)  52fe4284c3a36847f8024fa1     2.0
# 4     18.0              Rex (voice)  52fe4284c3a36847f8024fa5     2.0
#
#         id           name  order                      profile_path
# 0     31.0      Tom Hanks    0.0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg
# 1  12898.0      Tim Allen    1.0  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg
# 2   7167.0    Don Rickles    2.0  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg
# 3  12899.0     Jim Varney    3.0  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg
# 4  12900.0  Wallace Shawn    4.0  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg

# %%
# the ast.literal_eval means change the string to the python object, in this case, it will return to the list.
def parsed(x):
    if isinstance(x, str):
        return ast.literal_eval(x)
    else:
        return []

credits['cast_parsed'] = credits['cast'].apply(parsed)

# %%
tmdb_id = credits_df['id'].reset_index(drop = True)
tmdb_id.name = 'tmdb_id'
cast_df = pd.concat([
    tmdb_id,
    credits_sub_df.reset_index(drop = True)

],axis = 1 )

print(cast_df.head())
cast_df.shape
cast_df.columns.tolist()
# Out:
#    tmdb_id  cast_id                character                 credit_id  \
# 0      862     14.0            Woody (voice)  52fe4284c3a36847f8024f95
# 1      862     15.0   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99
# 2      862     16.0  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d
# 3      862     17.0       Slinky Dog (voice)  52fe4284c3a36847f8024fa1
# 4      862     18.0              Rex (voice)  52fe4284c3a36847f8024fa5
#
#    gender       id           name  order                      profile_path
# 0     2.0     31.0      Tom Hanks    0.0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg
# 1     2.0  12898.0      Tim Allen    1.0  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg
# 2     2.0   7167.0    Don Rickles    2.0  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg
# 3     2.0  12899.0     Jim Varney    3.0  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg
# 4     2.0  12900.0  Wallace Shawn    4.0  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg
# ['tmdb_id',
#  'cast_id',
#  'character',
#  'credit_id',
#  'gender',
#  'id',
#  'name',
# ...

# %%
# test 1 
# check id whether is the primary key 
# I decide the data
credits_sub_df.head()
cast_df_id  = credits_sub_df[['cast_id', 'name', 'gender']]
cast_df_clean = cast_df_id.drop_duplicates()

cast_df_clean
# Out:
#         cast_id               name  gender
# 0          14.0          Tom Hanks     2.0
# 1          15.0          Tim Allen     2.0
# 2          16.0        Don Rickles     2.0
# 3          17.0         Jim Varney     2.0
# 4          18.0      Wallace Shawn     2.0
# ...         ...                ...     ...
# 564884     19.0       Peter Dobson     2.0
# 564885     20.0   Darrell Dubovsky     0.0
# 564888      4.0       Pavel Pavlov     2.0
# 564889      5.0  Aleksandr Chabrov     0.0
# 564890      6.0        Vera Orlova     1.0
#
# [472477 rows x 3 columns]

# %%
# test whether the primary key is unique
# from the data we can manual clean the Ka-Fai Cheung, this is the same person because of name be changed, so it's fine.
# the other because we have 3 types of gender. We can decide because of the business rules only have female and male.

cast_df_clean[cast_df_clean.duplicated(subset = ['cast_id'], keep = False)]

# action
# filter out the gender who is gender 0.0 
# manaul clean the duplicates record again only appearance one. 
# write the logging information, then clean the dupliicates and only left one records.
# Out:
#         cast_id               name  gender
# 0          14.0          Tom Hanks     2.0
# 1          15.0          Tim Allen     2.0
# 2          16.0        Don Rickles     2.0
# 3          17.0         Jim Varney     2.0
# 4          18.0      Wallace Shawn     2.0
# ...         ...                ...     ...
# 564884     19.0       Peter Dobson     2.0
# 564885     20.0   Darrell Dubovsky     0.0
# 564888      4.0       Pavel Pavlov     2.0
# 564889      5.0  Aleksandr Chabrov     0.0
# 564890      6.0        Vera Orlova     1.0
#
# [472417 rows x 3 columns]

# %%
# test whether only 1 id match with 1 name 
result = cast_df_clean.groupby('cast_id')['name'].nunique()

problem_ids = result[result > 1]

print(problem_ids)

#40749	63574.0	Ka-Fai Cheung	2.0
#143289	63574.0	Cheung Ka-Fai	2.0

# that's because of this records should be fine.
# Out:
# cast_id
# 0.0        2447
# 1.0        8339
# 2.0       13143
# 3.0       16123
# 4.0       17869
#           ...
# 1106.0        2
# 1107.0        2
# 1108.0        2
# 1115.0        2
# 1116.0        2
# Name: name, Length: 515, dtype: int64

# %%
cast_df_clean[cast_df_clean['cast_id'] == 1]
# Out:
#         cast_id                   name  gender
# 13          1.0         Robin Williams     2.0
# 46          1.0        Whitney Houston     1.0
# 56          1.0           Steve Martin     2.0
# 133         1.0          Harrison Ford     2.0
# 197         1.0  Jean-Claude Van Damme     2.0
# ...         ...                    ...     ...
# 564656      1.0             Dona Speir     1.0
# 564782      1.0         Sridevi Kapoor     1.0
# 564791      1.0         Roberto Aguire     0.0
# 564842      1.0             Lisa Boyle     1.0
# 564858      1.0         Kourosh Tahami     0.0
#
# [8339 rows x 3 columns]

# %%
# test whether one 1 id match with 1 gender
result_age = cast_df_clean.groupby('cast_id')['name'].nunique() > 1 
problem_ids = result_age[result_age > 1 ]
print(problem_ids)
# the results is empty and i think the primary key should be id.
# Out:
# Series([], Name: name, dtype: bool)

# %% [markdown]
# # which is mean cast_id is not the id we want.

# %%
credits_sub_df.head()
cast_df_id  = credits_sub_df[['id', 'name', 'gender']]
cast_df_clean = cast_df_id.drop_duplicates()

cast_df_clean[cast_df_clean.duplicated(subset = ['id'], keep = False)]

-- 87662.0
# Out:
# 87662.0

# %%
cast_df_clean[cast_df_clean['id'] == 87662]
# same people wwho ahs differnet name.

cast_df_clean[cast_df_clean['id'] == 23764]
# same people with different name 
# 2 means male
# 1 means female
# Out:
#              id           name  gender
# 4872    23764.0  Эрика Элениак     1.0
# 564871  23764.0  Erika Eleniak     1.0

# %%
result_age = cast_df_clean.groupby('id')['name'].nunique() > 1 
problem_ids = result_age[result_age > 1 ]
print(problem_ids)
result_age = cast_df_clean.groupby('id')['gender'].nunique() > 1 
problem_ids = result_age[result_age > 1 ]
print(problem_ids)
# Out:
# Series([], Name: name, dtype: bool)
# Series([], Name: gender, dtype: bool)

# %% [markdown]
# # draft

# %%
# solution 
# find the dimension tabel we want 
# For the overall table ,clean the duplicates
# choose the pirmary key we wanna test ( this is for the local)
# make sure the primary key is not null ( when we're writing the code)
# make sure the primary key is unqiue (this is for the local)
# make sure the primarkey key is one key match with 1 column/records (this is local )

# ACTION[ cleaning]
# for the overall table, clean the duplicates. 
# clean the null variable for the primary key 
# check whether we have the duplicates rows 
# if we have, save the first records. 
# then genderate the table

# %%
# check for each column maximum length that is to support the data load into the mapping table
for col in cast_df_clean2.columns: 
    max_len = cast_df_clean2[col].astype(str).str.len().max()
    print(f"{col}, the max length is {max_len}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 2
#       1 # check for each column maximum length that is to support the data load into the mapping table
# ----> 2 for col in cast_df_clean2.columns:
#       3     max_len = cast_df_clean2[col].astype(str).str.len().max()
#       4     print(f"{col}, the max length is {max_len}")
#
# NameError: name 'cast_df_clean2' is not defined

# %%
movie_cast_table = cast_df[['tmdb_id', 'credit_id', 'id', 'cast_id', 'character', 'order']].copy()

# replace the name 
movie_cast_table = movie_cast_table.rename(columns={'id': 'actor_id'})

# drop na for the tmdb_id, credit_id ,and actor_id 
movie_cast_table = movie_cast_table.dropna(subset=['tmdb_id', 'credit_id', 'actor_id'])

# %%
for col in movie_cast_table.columns: 
    max_len = movie_cast_table[col].astype('str').str.len().max()
    print(f'{col} the max length is {max_len}')
# Out:
# tmdb_id the max length is 6
# credit_id the max length is 24
# actor_id the max length is 9
# cast_id the max length is 6
# character the max length is 390
# order the max length is 5

# %% [markdown]
# # crew df

# %%
credits['crew'] = credits['crew'].apply(parsed)
credits['crew'].head()
# Out:
# 0    [{'credit_id': '52fe4284c3a36847f8024f49', 'department': 'Directing', 'gender': 2, 'id': 7879, 'job': 'Director', 'name': 'John Lasseter', 'profile_path': '/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg'}, {'credit_id': '52fe4284c3a36847f8024f4f', 'department': 'Writing', 'gender': 2, 'id': 12891, 'job': 'Screenplay', 'name': 'Joss Whedon', 'profile_path': '/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg'}, {'credit_id': '52fe4284c3a36847f8024f55', 'department': 'Writing', 'gender': 2, 'id': 7, 'job': 'Screenplay', 'name': 'Andrew Stanton', 'profile_path': '/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg'}, {'credit_id': '52fe4284c3a36847f8024f5b', 'department': 'Writing', 'gender': 2, 'id': 12892, 'job': 'Screenplay', 'name': 'Joel Cohen', 'profile_path': '/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg'}, {'credit_id': '52fe4284c3a36847f8024f61', 'department': 'Writing', 'gender': 0, 'id': 12893, 'job': 'Screenplay', 'name': 'Alec Sokolow', 'profile_path': '/v79vlRYi94BZUQnkkyznbGUZLjT.jpg'}, {'credit_id': '52fe4284c3a36847f8024f67', 
# ...

# %%
crew_df = credits[['crew', 'id']].explode('crew')
print(crew_df.head())
# Out:
#                                                                                                                                                                                             crew  \
# 0  {'credit_id': '52fe4284c3a36847f8024f49', 'department': 'Directing', 'gender': 2, 'id': 7879, 'job': 'Director', 'name': 'John Lasseter', 'profile_path': '/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg'}
# 0   {'credit_id': '52fe4284c3a36847f8024f4f', 'department': 'Writing', 'gender': 2, 'id': 12891, 'job': 'Screenplay', 'name': 'Joss Whedon', 'profile_path': '/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg'}
# 0    {'credit_id': '52fe4284c3a36847f8024f55', 'department': 'Writing', 'gender': 2, 'id': 7, 'job': 'Screenplay', 'name': 'Andrew Stanton', 'profile_path': '/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg'}
# 0    {'credit_id': '52fe4284c3a36847f8024f5b', 'department': 'Writing', 'gender': 2, 'id': 12892, 'job': 'Screenplay', 'name': 'Joel Cohen', 'profile_path': '/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg'}
# ...

# %%
credits_sub_df = pd.json_normalize(crew_df['crew'])
credits_sub_df.head()
# Out:
#                   credit_id department  gender       id         job  \
# 0  52fe4284c3a36847f8024f49  Directing     2.0   7879.0    Director
# 1  52fe4284c3a36847f8024f4f    Writing     2.0  12891.0  Screenplay
# 2  52fe4284c3a36847f8024f55    Writing     2.0      7.0  Screenplay
# 3  52fe4284c3a36847f8024f5b    Writing     2.0  12892.0  Screenplay
# 4  52fe4284c3a36847f8024f61    Writing     0.0  12893.0  Screenplay
#
#              name                      profile_path
# 0   John Lasseter  /7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg
# 1     Joss Whedon  /dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg
# 2  Andrew Stanton  /pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg
# 3      Joel Cohen  /dAubAiZcvKFbboWlj7oXOkZnTSu.jpg
# 4    Alec Sokolow  /v79vlRYi94BZUQnkkyznbGUZLjT.jpg

# %%
#print(credits_sub_df['department'].unique())

#print(credits_sub_df['job'].unique())

# %%
# this is the director
credits_sub_df[credits_sub_df['job'] == 'Director'].head()
# Out:
#                     credit_id department  gender       id       job  \
# 0    52fe4284c3a36847f8024f49  Directing     2.0   7879.0  Director
# 109  52fe44bfc3a36847f80a7c7d  Directing     2.0   4945.0  Director
# 122  52fe466a9251416c75077a89  Directing     2.0  26502.0  Director
# 126  52fe44779251416c91011acb  Directing     2.0   2178.0  Director
# 141  52fe44959251416c75039eef  Directing     2.0  56106.0  Director
#
#                 name                      profile_path
# 0      John Lasseter  /7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg
# 109     Joe Johnston   /fok4jaO62v5IP6hkpaaAcXuw2H.jpg
# 122    Howard Deutch  /68Vae1HkU1NxQZ6KEmuxIpno7c9.jpg
# 126  Forest Whitaker  /4pMQkelS5lK661m9Kz3oIxLYiyS.jpg
# 141    Charles Shyer  /hnWGd74CbmTcDCFQiJ8SYLazIXW.jpg

# %%
# this is the writor
credits_sub_df[credits_sub_df['job'] == 'Screenplay'].head()
# Out:
#                     credit_id department  gender       id         job  \
# 1    52fe4284c3a36847f8024f4f    Writing     2.0  12891.0  Screenplay
# 2    52fe4284c3a36847f8024f55    Writing     2.0      7.0  Screenplay
# 3    52fe4284c3a36847f8024f5b    Writing     2.0  12892.0  Screenplay
# 4    52fe4284c3a36847f8024f61    Writing     0.0  12893.0  Screenplay
# 107  52fe44bfc3a36847f80a7c89    Writing     2.0    876.0  Screenplay
#
#                    name                      profile_path
# 1           Joss Whedon  /dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg
# 2        Andrew Stanton  /pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg
# 3            Joel Cohen  /dAubAiZcvKFbboWlj7oXOkZnTSu.jpg
# 4          Alec Sokolow  /v79vlRYi94BZUQnkkyznbGUZLjT.jpg
# 107  Jonathan Hensleigh  /l1c4UFD3g0HVWj5f0CxXAvMAGiT.jpg

# %%
# this is the writor
credits_sub_df[credits_sub_df['job'] == 'Screenplay'].head()
# Out:
#                     credit_id department  gender       id         job  \
# 1    52fe4284c3a36847f8024f4f    Writing     2.0  12891.0  Screenplay
# 2    52fe4284c3a36847f8024f55    Writing     2.0      7.0  Screenplay
# 3    52fe4284c3a36847f8024f5b    Writing     2.0  12892.0  Screenplay
# 4    52fe4284c3a36847f8024f61    Writing     0.0  12893.0  Screenplay
# 107  52fe44bfc3a36847f80a7c89    Writing     2.0    876.0  Screenplay
#
#                    name                      profile_path
# 1           Joss Whedon  /dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg
# 2        Andrew Stanton  /pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg
# 3            Joel Cohen  /dAubAiZcvKFbboWlj7oXOkZnTSu.jpg
# 4          Alec Sokolow  /v79vlRYi94BZUQnkkyznbGUZLjT.jpg
# 107  Jonathan Hensleigh  /l1c4UFD3g0HVWj5f0CxXAvMAGiT.jpg

# %%
credits_sub_df.shape
# Out:
# (465085, 7)

# %%
credits_sub_df.duplicated().sum()

# id in the duplicated rows is not the same.
credits_sub_df['id'].duplicated().sum()
# Out:
# np.int64(303509)

# %%
crew_df = credits[['crew', 'id']].explode('crew')
crew_df.head()
# Out:
#                                                                                                                                                                                             crew  \
# 0  {'credit_id': '52fe4284c3a36847f8024f49', 'department': 'Directing', 'gender': 2, 'id': 7879, 'job': 'Director', 'name': 'John Lasseter', 'profile_path': '/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg'}
# 0   {'credit_id': '52fe4284c3a36847f8024f4f', 'department': 'Writing', 'gender': 2, 'id': 12891, 'job': 'Screenplay', 'name': 'Joss Whedon', 'profile_path': '/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg'}
# 0    {'credit_id': '52fe4284c3a36847f8024f55', 'department': 'Writing', 'gender': 2, 'id': 7, 'job': 'Screenplay', 'name': 'Andrew Stanton', 'profile_path': '/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg'}
# 0    {'credit_id': '52fe4284c3a36847f8024f5b', 'department': 'Writing', 'gender': 2, 'id': 12892, 'job': 'Screenplay', 'name': 'Joel Cohen', 'profile_path': '/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg'}
# ...

# %%
credits_sub_df = pd.json_normalize(crew_df['crew'])
credits_sub_df.head()
# Out:
#                   credit_id department  gender       id         job  \
# 0  52fe4284c3a36847f8024f49  Directing     2.0   7879.0    Director
# 1  52fe4284c3a36847f8024f4f    Writing     2.0  12891.0  Screenplay
# 2  52fe4284c3a36847f8024f55    Writing     2.0      7.0  Screenplay
# 3  52fe4284c3a36847f8024f5b    Writing     2.0  12892.0  Screenplay
# 4  52fe4284c3a36847f8024f61    Writing     0.0  12893.0  Screenplay
#
#              name                      profile_path
# 0   John Lasseter  /7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg
# 1     Joss Whedon  /dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg
# 2  Andrew Stanton  /pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg
# 3      Joel Cohen  /dAubAiZcvKFbboWlj7oXOkZnTSu.jpg
# 4    Alec Sokolow  /v79vlRYi94BZUQnkkyznbGUZLjT.jpg

# %%
# take the information that I need, concat the new table then to find the primary key for the crew people. 

tmdb_id = crew_df['id'].reset_index(drop = True)
tmdb_id.name = 'tmdb_id'
final_crew_df = pd.concat(
[tmdb_id, 
credits_sub_df[['credit_id','department', 'gender', 'id', 'job','name','profile_path']].reset_index(drop = True )
],axis = 1 
)
print(final_crew_df.shape)


final_crew_df.head()
# Out:
# (465085, 8)
#    tmdb_id                 credit_id department  gender       id         job  \
# 0      862  52fe4284c3a36847f8024f49  Directing     2.0   7879.0    Director
# 1      862  52fe4284c3a36847f8024f4f    Writing     2.0  12891.0  Screenplay
# 2      862  52fe4284c3a36847f8024f55    Writing     2.0      7.0  Screenplay
# 3      862  52fe4284c3a36847f8024f5b    Writing     2.0  12892.0  Screenplay
# 4      862  52fe4284c3a36847f8024f61    Writing     0.0  12893.0  Screenplay
#
#              name                      profile_path
# 0   John Lasseter  /7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg
# 1     Joss Whedon  /dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg
# 2  Andrew Stanton  /pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg
# 3      Joel Cohen  /dAubAiZcvKFbboWlj7oXOkZnTSu.jpg
# 4    Alec Sokolow  /v79vlRYi94BZUQnkkyznbGUZLjT.jpg

# %%
#478
print(final_crew_df.duplicated().sum())
final_crew_df.drop_duplicates(inplace = True)
print(final_crew_df.duplicated().sum())
print(len(final_crew_df))


# crew primary id = tmdb_id, id, job.
final_crew_df[['tmdb_id','id', 'job']].duplicated().sum()
#final_crew_df[['tmdb_id','id']].duplicated().sum()
#, 'name'
# Out:
# 478
# 0
# 464607
# np.int64(0)

# %%
# trying to find the key for the crew, movie and mapping table. 
for col in final_crew_df.columns: 
    print(f' {col}: {final_crew_df[col].nunique()}, {len(final_crew_df)}')

print(final_crew_df.columns.tolist())
# find mapping table primary key 
print('Here is the result ')

# id is the primary key 
crew_df_final = final_crew_df[['id', 'gender','name']].drop_duplicates()

crew_df_final = crew_df_final.drop_duplicates(subset = ['id'])

print(crew_df_final.shape[0], len(crew_df_final))

#primary_key = cast_df[[ 'credit_id','tmdb_id']].drop_duplicates().shape[0]
#print(f'credit_id and tmdb_id {primary_key}, {len(cast_df)}'）
# Out:
#  tmdb_id: 45432, 464607
#  credit_id: 463836, 464607
#  department: 12, 464607
#  gender: 3, 464607
#  id: 161575, 464607
#  job: 456, 464607
#  name: 157614, 464607
#  profile_path: 13347, 464607
# ['tmdb_id', 'credit_id', 'department', 'gender', 'id', 'job', 'name', 'profile_path']
# Here is the result
# 161576 161576

# %%
for col in crew_df_final.columns: 
    max_len = crew_df_final[col].astype('str').str.len().max()
    print(f'{col} the max length is {max_len}')
# Out:
# id the max length is 9
# gender the max length is 3
# name the max length is 44

# %%
def check_pk(df, cols):
    clean_df = df.dropna(subset=cols)
    unique_rows = clean_df[cols].drop_duplicates().shape[0]
    total_rows = len(clean_df)

    print(f"Checking: {cols}")
    print(f"Unique rows: {unique_rows}")
    print(f"Total rows : {total_rows}")

    if unique_rows == total_rows:
        print("✅ candidate primary key\n")
    else:
        print("❌ not unique\n")
        



crew_movie_mapping = final_crew_df[['tmdb_id', 'id', 'department', 'credit_id', 'job']].copy()
crew_movie_mapping = crew_movie_mapping.drop_duplicates()

check_pk(crew_movie_mapping, ['tmdb_id', 'credit_id'])
check_pk(crew_movie_mapping, ['tmdb_id', 'id', 'job'])
check_pk(crew_movie_mapping, ['tmdb_id', 'id', 'department', 'job'])
check_pk(crew_movie_mapping, ['tmdb_id', 'id', 'department', 'credit_id', 'job'])


#movie_cast_table = movie_cast_table.dropna(subset=['tmdb_id', 'credit_id', 'actor_id'])
# Out:
# Checking: ['tmdb_id', 'credit_id']
# Unique rows: 463836
# Total rows : 463836
# ✅ candidate primary key
#
# Checking: ['tmdb_id', 'id', 'job']
# Unique rows: 463836
# Total rows : 463836
# ✅ candidate primary key
#
# Checking: ['tmdb_id', 'id', 'department', 'job']
# Unique rows: 463836
# Total rows : 463836
# ✅ candidate primary key
#
# Checking: ['tmdb_id', 'id', 'department', 'credit_id', 'job']
# Unique rows: 463836
# Total rows : 463836
# ✅ candidate primary key

# %%
for col in crew_movie_mapping.columns: 
    max_len = crew_movie_mapping[col].astype('str').str.len().max()
    print(f'{col} the max length is {max_len}')
# Out:
# tmdb_id the max length is 6
# id the max length is 9
# department the max length is 17
# credit_id the max length is 24
# job the max length is 56

# %%
# draft downbelow

# %%
def parsed(x):
    # return list of dic format or return to list.
    if isinstance(x,str): 
        return ast.literal_eval(x)
    return []

credits['crew_parsed'] = credits['crew'].apply(parsed)
credits['cast_parsed'] = credits['cast'].apply(parsed)

# %%
# cast info
target_id = '52fe4284c3a36847f8024f95'
for idx, crew_list in enumerate(credits['crew_parsed']):
    for crew in crew_list: 
        if crew['credit_id'] == target_id: 
            print(crew)

# which means they don't have relaionship  with each other.

# %%
target_id_crew = '52fe4284c3a36847f8024f49'
for idx, cast_list in enumerate(credits['cast_parsed']): 
    for cast in cast_list: 
        if cast['credit_id'] == target_id_crew:
            print(cast)
# which means they don't have the reslitionship with each other.

# %% [markdown]
# so it means i nthe credits.csv file, it has 2 entities.
# One is called crew entity, the another one is called cast entity.
#
# I want to make it flatten to create it as 2 table
#
#
# Before we do it, I want to know howw many keys do we have.

# %%
# store all of the keys to avoid the dulplicates
all_crew_keys = set()

for crew_list in credits['cast_parsed']: 
    for crew in crew_list: 
        all_crew_keys.update(crew.keys())
print(all_crew_keys)

# %%
# I want to know the total id. the number of information data id. 
# I want to make it flatten. 
# list of dict change to the one dict per row at the same time define the columns. 
# use for it to create a table.

# %%
# flatten the data 
# explode the data (flatten the data)

# cast 

cast_explode = credits[['id', 'cast_parsed']].explode('cast_parsed')
cast_explode.head()

# %%
# crew 
crew_explode = credits[['id', 'crew_parsed']].explode('crew_parsed')
crew_explode.head()

# %%
cast_details = pd.json_normalize(cast_explode['cast_parsed'])
cast_details

# %%
# 检查 credit_id 单独是否 unique
print("credit_id unique?", cast_details['credit_id'].is_unique)

# 检查 cast_id + credit_id 组合是否 unique
print("cast_id + credit_id unique?", 
      cast_details[['cast_id', 'credit_id', 'id']].duplicated().sum() == 0)

# 检查 credit_id 是否可以单独做 PK
print("credit_id has nulls?", cast_details['credit_id'].isnull().sum())

# %%
crew_details = pd.json_normalize(crew_explode['crew_parsed'])
crew_details

# %%
crew_details = pd.concat(
    [crew_explode[['id']].reset_index(drop=True),
     crew_details.reset_index(drop=True)],
    axis=1
)

# %%
crew_details

# %%
cast_details = pd.concat(
    [cast_details[['id']].reset_index(drop=True),
     cast_details.reset_index(drop=True)],
    axis=1
)

# %% [markdown]
# credit_id dulplicates

# %%
# I want to see whether credit id is unique for the above 2 table.
# for the credit_id they have the dulplicated. 
cast_details['credit_id'].duplicated().sum()

# %%
crew_details['credit_id'].duplicated().sum()

# %% [markdown]
# rows duplicates

# %%
# they have 1248 rows of dulplicated.

crew_details.duplicated().sum()

# %%
cast_details.duplicated().sum()

# %% [markdown]
# # maybe clean the dulplicates, then they're are all the unique. need to double check about it.

# %%
crew_details['id'].duplicated().sum()

# %%
cast_details['id'].duplicated().sum()

# %% [markdown]
# I think id is the unique information.

# %%
cast_details[['credit_id', 'id']].duplicated().sum()

# %%
crew_details[['credit_id' , 'id']].duplicated().sum()

# %%
"[{'cast_id': 11,
 'character': 'Django',
'credit_id': '52fe4b69c3a36847f8202657',
'gender': 2, 'id': 20581, 
'name': 'Jack Betts',
'order': 0, 'profile_path': '/f03shMGYcbPG2EyjkIVAR0YA1RA.jpg'},
{'cast_id': 12, 'character': 'Sheriff Jack Ronson / Sartana', 'credit_id': '52fe4b69c3a36847f820265b', 'gender': 2, 'id': 21181, 'name': 'Fabio Testi', 'order': 1, 'profile_path': '/qqE1Vh8guRCoIGkfNRuE0mXx0vL.jpg'},
{'cast_id': 13, 'character': 'Bud Willer / Wheeler', 'credit_id': '52fe4b69c3a36847f820265f', 'gender': 0, 'id': 43884, 'name': 'Dino Strano', 'order': 2, 'profile_path': None},
{'cast_id': 14, 'character': 'Deputy Sheriff Mason', 'credit_id': '52fe4b69c3a36847f8202663', 'gender': 0, 'id': 1126337, 'name': 'Calgero Caruana', 'order': 3, 'profile_path': None}, 
{'cast_id': 15, 'character': 'Paco Sanchez', 'credit_id': '52fe4b69c3a36847f8202667', 'gender': 2, 'id': 27412, 'name': 'Benito Pacifico', 'order': 4, 'profile_path': '/2FuGAZM22iS58nWpxqGYQTT8ncp.jpg'},
{'cast_id': 16, 'character': 'Widow Sturges', 'credit_id': '52fe4b69c3a36847f820266b', 'gender': 1, 'id': 30902, 'name': 'Simonetta Vitelli', 'order': 5, 'profile_path': '/jMnRUMgLV3l6lyB26bd8t9b11m5.jpg'},
{'cast_id': 17, 'character': ""Joe 'The Worm' Smith"", 'credit_id': '52fe4b69c3a36847f820266f', 'gender': 2, 'id': 72475, 'name': 'Luciano Conti', 'order': 6, 'profile_path': None},
{'cast_id': 18, 'character': 'Mordera', 'credit_id': '52fe4b69c3a36847f8202673', 'gender': 0, 'id': 1120103, 'name': 'Roberto Danesi', 'order': 7, 'profile_path': None},
{'cast_id': 19, 'character': 'Bill / Willy McLaren', 'credit_id': '52fe4b69c3a36847f8202677', 'gender': 0, 'id': 43241, 'name': 'Attilio Dottesio', 'order': 8, 'profile_path': None}, 
{'cast_id': 20, 'character': 'Frank Cutler', 'credit_id': '52fe4b69c3a36847f820267b', 'gender': 0, 'id': 1126166, 'name': 'Celso Faria', 'order': 9, 'profile_path': '/q1wBCpbsGBehRt7PHOZ7hxsKTw3.jpg'}, 
{'cast_id': 21, 'character': 'Peter', 'credit_id': '52fe4b69c3a36847f820267f', 'gender': 0, 'id': 1024363, 'name': 'Franco Pasquetto', 'order': 10, 'profile_path': None}, 
{'cast_id': 22, 'character': 'Dolores', 'credit_id': '52fe4b69c3a36847f8202683', 'gender': 0, 'id': 1121928, 'name': 'Mariella Palmich', 'order': 11, 'profile_path': None}]",
"[{'credit_id': '52fe4b69c3a36847f8202689', 'department': 'Camera', 'gender': 0, 'id': 41065, 'job': 'Director of Photography', 'name': 'Franco Villa', 'profile_path': None}, "
"{'credit_id': '52fe4b69c3a36847f8202647', 'department': 'Sound', 'gender': 0, 'id': 44975, 'job': 'Original Music Composer', 'name': 'Coriolano Gori', 'profile_path': None}, {'credit_id': '52fe4b69c3a36847f820262f', 'department': 'Writing', 'gender': 0, 'id': 1046507, 'job': 'Screenplay', 'name': 'Demofilo Fidani', 'profile_path': None}, {'credit_id': '52fe4b69c3a36847f8202623', 'department': 'Directing', 'gender': 0, 'id': 1046507, 'job': 'Director', 'name': 'Demofilo Fidani', 'profile_path': None}, {'credit_id': '52fe4b69c3a36847f8202641', 'department': 'Production', 'gender': 0, 'id': 1046507, 'job': 'Producer', 'name': 'Demofilo Fidani', 'profile_path': None}, {'credit_id': '52fe4b69c3a36847f8202629', 'department': 'Writing', 'gender': 0, 'id': 1046507, 'job': 'Story', 'name': 'Demofilo Fidani', 'profile_path': None}, {'credit_id': '52fe4b69c3a36847f820264d', 'department': 'Editing', 'gender': 0, 'id': 1046519, 'job': 'Editor', 'name': 'Piera Bruni', 'profile_path': None}, {'credit_id': '52fe4b69c3a36847f8202635', 'department': 'Writing', 'gender': 0, 'id': 1046522, 'job': 'Screenplay', 'name': 'Mila Vitelli Valenza', 'profile_path': None}, {'credit_id': '52fe4b69c3a36847f820263b', 'department': 'Production', 'gender': 0, 'id': 1086945, 'job': 'Producer', 'name': 'Otello Cocchi', 'profile_path': None}, {'credit_id': '52fe4b69c3a36847f8202653', 'department': 'Camera', 'gender': 0, 'id': 1125523, 'job': 'Camera Operator', 'name': 'Claudio Morabito', 'profile_path': None}]",115353

# %% [markdown]
# credit_id maybe is the unique id, but the id is not the unique id

# %% [markdown]
# # KEYWORDS.CSV

# %%
keywords = pd.read_csv('../src/keywords.csv')
print(keywords.shape)
print(keywords.columns)
# Out:
# (46419, 2)
# Index(['id', 'keywords'], dtype='object')

# %%
# change to the list of dict. 
def parsed(x):
    # return list of dic format or return to list.
    if isinstance(x,str): 
        return ast.literal_eval(x)
    return []

keywords['keywords_parsed'] = keywords['keywords'].apply(parsed)

# %%
keywords['keywords_parsed']
# Out:
# 0                                    [{'id': 931, 'name': 'jealousy'}, {'id': 4290, 'name': 'toy'}, {'id': 5202, 'name': 'boy'}, {'id': 6054, 'name': 'friendship'}, {'id': 9713, 'name': 'friends'}, {'id': 9823, 'name': 'rivalry'}, {'id': 165503, 'name': 'boy next door'}, {'id': 170722, 'name': 'new toy'}, {'id': 187065, 'name': 'toy comes to life'}]
# 1                                                                                                                [{'id': 10090, 'name': 'board game'}, {'id': 10941, 'name': 'disappearance'}, {'id': 15101, 'name': 'based on children's book'}, {'id': 33467, 'name': 'new home'}, {'id': 158086, 'name': 'recluse'}, {'id': 158091, 'name': 'giant insect'}]
# ...

# %%
# check the unique key.
# store all of the keys to avoid the dulplicates
all_keywords_keys = set()

for key_list in keywords['keywords_parsed']: 
    for item in key_list: 
        all_keywords_keys.update(item.keys())
print(all_keywords_keys)
# Out:
# {'name', 'id'}

# %%
# flatten the data. 
keywords_explode = keywords[['id', 'keywords_parsed']].explode('keywords_parsed')
keywords_explode
# Out:
#            id                     keywords_parsed
# 0         862     {'id': 931, 'name': 'jealousy'}
# 0         862         {'id': 4290, 'name': 'toy'}
# 0         862         {'id': 5202, 'name': 'boy'}
# 0         862  {'id': 6054, 'name': 'friendship'}
# 0         862     {'id': 9713, 'name': 'friends'}
# ...       ...                                 ...
# 46415  111109       {'id': 14531, 'name': 'play'}
# 46415  111109     {'id': 215397, 'name': 'pinoy'}
# 46416   67758                                 NaN
# 46417  227506                                 NaN
# 46418  461257                                 NaN
#
# [173475 rows x 2 columns]

# %%
keywords_details = pd.json_normalize(keywords_explode['keywords_parsed'])
keywords_details
# Out:
#               id        name
# 0          931.0    jealousy
# 1         4290.0         toy
# 2         5202.0         boy
# 3         6054.0  friendship
# 4         9713.0     friends
# ...          ...         ...
# 173470   14531.0        play
# 173471  215397.0       pinoy
# 173472       NaN         NaN
# 173473       NaN         NaN
# 173474       NaN         NaN
#
# [173475 rows x 2 columns]

# %%
keywords_details['id'].duplicated().sum()
# Out:
# np.int64(153518)

# %%
keywords_details.duplicated().sum()
# we have 153518 rows of dulplicated.
# Out:
# np.int64(153518)

# %%
keywords[['id']].duplicated().sum()
# Out:
# np.int64(987)

# %%
keywords_details = pd.concat(
    [keywords[['id']].reset_index(drop=True),
     keywords_details.reset_index(drop=True)],
    axis=1
)

# %%
keywords_details
# Out:
#              id        id        name
# 0         862.0     931.0    jealousy
# 1        8844.0    4290.0         toy
# 2       15602.0    5202.0         boy
# 3       31357.0    6054.0  friendship
# 4       11862.0    9713.0     friends
# ...         ...       ...         ...
# 173470      NaN   14531.0        play
# 173471      NaN  215397.0       pinoy
# 173472      NaN       NaN         NaN
# 173473      NaN       NaN         NaN
# 173474      NaN       NaN         NaN
#
# [173475 rows x 3 columns]

# %%
keywords_details.duplicated().sum()
# Out:
# np.int64(109835)

# %% [markdown]
# Links table

# %%
links = pd.read_csv('../src/links_small.csv')
# this is the main table, they don't have the duplicates. 
# movieId,imdbId,tmdbId

print(links.shape)
print(links.columns)


# movieId', 'imdbId', 'tmdbId' combination is unique
print(links.duplicated().sum())

print(links['movieId'].duplicated().sum())

# tmdid is not duplicate,

print(links['tmdbId'].duplicated().sum())

#imdbid is unique.
print(links['imdbId'].duplicated().sum())
# Out:
# (9125, 3)
# Index(['movieId', 'imdbId', 'tmdbId'], dtype='object')
# 0
# 0
# 12
# 0

# %% [markdown]
# # movie metadata

# %%
import pandas as pd 
movie_metadata = pd.read_csv('../src/movies_metadata.csv')
print(movie_metadata.shape)
print(movie_metadata.columns)
# Out:
# (45466, 24)
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')
# /var/folders/rt/2qm8vc4d2z5429h4tm7j7pkr0000gn/T/ipykernel_7698/584530527.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie_metadata = pd.read_csv('../src/movies_metadata.csv')

# %%
pd.set_option('display.max_columns', None)

movie_metadata.head()
# Out:
#    adult  \
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
#                                                                                                                                              belongs_to_collection  \
# 0            {'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}
# 1                                                                                                                                                              NaN
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collection', 'poster_path': '/nLvUdqgPgm3F85NMCii9gVFUcet.jpg', 'backdrop_path': '/hypTnLot2z8wpFS7qwsQHW1uV8u.jpg'}
# 3                                                                                                                                                              NaN
# ...

# %% [markdown]
# # define the movie primary key

# %%
import pandas as pd 

movies = pd.read_csv('movies_metadata.csv',low_memory=False)
# 45466 rows and 24 columns.
#print(movies.shape)

# number of 45436 unique value
#movies['id'].nunique()


# 45466
#print(len(movies))

# no null null value for the id column.
#print(movies['id'].isnull().sum())


# dashboaard1: 
# movie_trend table
movie_overall_table = movies[['id', 'imdb_id', 'revenue','budget','release_date', 'budget', 'runtime']]
#print(movie_overall_table.duplicated().sum())
movie_overall_table.drop_duplicates(inplace = True)
#print(movie_overall_table.duplicated().sum())

print(movie_overall_table.shape[0])
print(movie_overall_table['id'].nunique())   
print(movie_overall_table['id'].duplicated().sum())   
# tmdbid is the primary key for the dashboard1 table. 

# genres table
# imdb_db, tmdb_id , genres
# Out:
# 45436
# 45436
# 0
# /var/folders/rt/2qm8vc4d2z5429h4tm7j7pkr0000gn/T/ipykernel_26705/4031478273.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_overall_table.drop_duplicates(inplace = True)

# %% [markdown]
# ## check the tmdb_id column in the movie dataset

# %%
# find bad row for the id column.
bad_row = movies[pd.to_numeric(movies['id'], errors = 'coerce').isna()]
print(f'{len(bad_row)}')
bad_row['id']


# find the non-reasonable data. 
movies = movies.dropna(subset=['id'])
# set it up as string

movies['id'] = movies['id'].astype(str)
print(movies['id'].str.len().max() )
# from the result we find the length of the movie id = 10 
print(movies['id'][movies['id'].str.len() == 10])

# then we find the id type become the 1997-08-20, so we're going to clean the data. 

movies['id'] = pd.to_numeric(movies['id'], errors = 'coerce')
movies.dropna(subset = ['id'])
movies['id'] = movies['id'].astype(int).astype(str)
print(f'Here is the max length {movies['id'].str.len().max()}')
print(movies['id'][movies['id'].str.len() == movies['id'].str.len().max()])

# check the data whether have the null value. 
print(movies['id'].isna().any())
# no null value
# Out:
# 0
# 6
# Series([], Name: id, dtype: object)
# Here is the max length 6
# 36       139405
# 50       117164
# 55       124057
# 76       124626
# 82       146599
#           ...
# 45459    222848
# 45461    439050
# 45462    111109
# 45464    227506
# 45465    461257
# Name: id, Length: 16065, dtype: object
# False

# %% [markdown]
# ## check the title column in the movie data

# %%
# check the data whethe have the null value
#print(movies['title'].isna().any())

# find title data whether have the correct format.
#movies['title'].astype(str)

print(movies['title'].str.len().max())
print(movies[movies['title'].str.len() == movies['title'].str.len().max()])
# Out:
# 105
#        adult belongs_to_collection  budget  \
# 36911  False                   NaN       0
#
#                                     genres homepage      id    imdb_id  \
# 36911  [{'id': 99, 'name': 'Documentary'}]      NaN  268669  tt0037993
#
#       original_language  \
# 36911                en
#
#                                                                                                       original_title  \
# 36911  Pobeda na Pravoberezhnoi Ukraine i izgnaniye nemetsikh zakhvatchikov za predeli Ukrainskikh sovietskikh zemel
#
#                                                               overview  \
# 36911  Dovzhenko and Solntseva's documentary about the end of the war.
#
#       popularity                       poster_path production_companies  \
# 36911   0.001177  /nQect9RmNXvMOnVsznyuGYqmlXk.jpg                   []
#
#       production_countries release_date  revenue  runtime spoken_languages  \
# ...

# %% [markdown]
# ## check the production company in the movie dataset

# %%
movies.columns.to_list()
type(movies['production_companies'])
# Out:
# pandas.core.series.Series

# %%
# 1. 先算出最大长度
max_len = movies['title'].str.len().max()
print(f"最长标题的长度: {max_len}")

# 2. 找出长度等于最大值的那些行
longest = movies[movies['title'].str.len() == max_len]
print(longest)
# Out:
# 最长标题的长度: 105
#        adult belongs_to_collection  budget  \
# 36911  False                   NaN       0
#
#                                     genres homepage      id    imdb_id  \
# 36911  [{'id': 99, 'name': 'Documentary'}]      NaN  268669  tt0037993
#
#       original_language  \
# 36911                en
#
#                                                                                                       original_title  \
# 36911  Pobeda na Pravoberezhnoi Ukraine i izgnaniye nemetsikh zakhvatchikov za predeli Ukrainskikh sovietskikh zemel
#
#                                                               overview  \
# 36911  Dovzhenko and Solntseva's documentary about the end of the war.
#
#       popularity                       poster_path production_companies  \
# 36911   0.001177  /nQect9RmNXvMOnVsznyuGYqmlXk.jpg                   []
#
#       production_countries release_date  revenue  runtime spoken_languages  \
# ...

# %%
import ast
pd.set_option('display.max_columns', None)
movies.head()

def parsed(x):
    # return list of dic format or return to list.
    if isinstance(x,str): 
        return ast.literal_eval(x)
    return []

movies['production_companies_parsed'] = movies['production_companies'].apply(parsed)
exploded = movies[['id', 'title', 'production_companies_parsed']].explode('production_companies_parsed')



companies_flat = pd.json_normalize(exploded['production_companies_parsed'])



companies_flat = companies_flat['name'].str.len().max()
print(companies_flat)

# change the budget



# 把脏数据变 NaN
movies['budget'] = pd.to_numeric(movies['budget'], errors='coerce')

# 丢掉 NaN 行(可选,看你要不要保留)
movies = movies.dropna(subset=['budget'])

# 现在可以安全转 int 再算长度
budget_len = movies['budget'].astype(int).astype(str).str.len()
print(f"budget 最大长度: {budget_len.max()}")
print(f"budget 最小长度: {budget_len.min()}")


# change the dirty data the NAN 
movies['revenue'] = pd.to_numeric(movies['revenue'], errors='coerce')

# 丢掉 NaN 行
movies = movies.dropna(subset=['revenue'])

# 现在可以安全转 int 再算长度
revenue_len = movies['revenue'].astype(int).astype(str).str.len()
print(f"revenue 最大长度: {revenue_len.max()}")
print(f"revenue 最小长度: {revenue_len.min()}")


# 最大值是多少,位数就是多少
max_runtime = pd.to_numeric(movies['runtime'], errors='coerce').max()
max_len = len(str(int(max_runtime)))
print(f"runtime 最大位数: {max_len}")

# 一行搞定:脏数据和空值自动变 NaT,保留所有行
movies['release_date'] = pd.to_datetime(movies['release_date'], errors='coerce')

# 看看清洗效果

print(f"dtype: {movies['release_date'].dtype}")             # datetime64[ns]
print(f"缺失/脏数据行数: {movies['release_date'].isna().sum()}")
print(movies[['title', 'release_date']].head())
# Out:
# 101.0
# budget 最大长度: 9
# budget 最小长度: 1
# revenue 最大长度: 10
# revenue 最小长度: 1
# runtime 最大位数: 4
# dtype: datetime64[ns]
# 缺失/脏数据行数: 84
#                          title release_date
# 0                    Toy Story   1995-10-30
# 1                      Jumanji   1995-12-15
# 2             Grumpier Old Men   1995-12-22
# 3            Waiting to Exhale   1995-12-22
# 4  Father of the Bride Part II   1995-02-10

# %% [markdown]
# # define genres table primary key.

# %%
import ast 
def parsed(x):
    # return list of dic format or return to list.
    if isinstance(x,str): 
        return ast.literal_eval(x)
    return []
movies['genres_parsed'] = movies['genres'].apply(parsed)
genres_explode = movies[['id','imdb_id','genres_parsed']].explode('genres_parsed')
#print(genres_explode.head())

genres_df= pd.json_normalize(genres_explode['genres_parsed'])
#print(genres_array.head())
# set it as genre, we can see genres_id and genres_name are the name 
print(genres_df['id'].nunique())
print(genres_df['name'].nunique())







print(genres_df.head())
# Out:
# 20
# 20
#         id       name
# 0     16.0  Animation
# 1     35.0     Comedy
# 2  10751.0     Family
# 3     12.0  Adventure
# 4     14.0    Fantasy

# %%
for col in genres_df.columns: 
    max_len = genres_df[col].astype('str').str.len().max()
    print(f'{col} the max length is {max_len}')
# Out:
# id the max length is 7
# name the max length is 15

# %%
# 79
#genres_df.duplicated().sum()
#(93548, 3)
#genres_df.shape

genres_df.drop_duplicates(inplace = True)
#print(genres_df.duplicated().sum())
# (93469, 3)
genres_df.shape
# trying to find the genre unique data. 
# 45417
print(genres_df['imdb_id'].nunique())
# 45436
print(genres_df['tmdb_id'].nunique())

print(genres_df[['imdb_id', 'tmdb_id']].nunique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'imdb_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[291], line 12
#       9 genres_df.shape
# ...

# %%
for columns

# %%
print("Unique id:", movie_metadata[['id','imdb_id']].nunique())
print("Is unique:", movie_metadata['id'].is_unique)
print("Total rows:", len(movie_metadata))
print("Is unique:", movie_metadata.nunique())
movie_metadata['genres'][0]

# %%
def parsed(x):
    # return list of dic format or return to list.
    if isinstance(x,str): 
        return ast.literal_eval(x)
    return []



cols_to_parse = ['belongs_to_collection', 'genres', 'spoken_languages']


movie_metadata['belongs_to_collection_parsed'] = movie_metadata['belongs_to_collection'].apply(parsed)
movie_metadata['genres_parsed'] = movie_metadata['genres'].apply(parsed)
movie_metadata['spoken_languages_parsed'] = movie_metadata['spoken_languages'].apply(parsed)

# %%
type(movie_metadata['belongs_to_collection_parsed'][0])

# %%
False,
"{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}",
30000000,
"[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]",http://toystory.disney.com/toy-story,862,tt0114709,en,Toy Story,"Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences.",21.946943,/rhIRbceoE9lR4veEXuwCC2wARtG.jpg,"[{'name': 'Pixar Animation Studios', 'id': 3}]","[{'iso_3166_1': 'US', 'name': 'United States of America'}]",1995-10-30,373554033,81.0,"[{'iso_639_1': 'en', 'name': 'English'}]",Released,,Toy Story,False,7.7,5415

# %%
collection_details = pd.json_normalize(movie_metadata['belongs_to_collection_parsed'])
collection_details.head()

# %%
genres_explode = movie_metadata[['id','imdb_id','genres_parsed']].explode('genres_parsed')
genres_explode.head()

# %%
spoken_language_explode = movie_metadata[['id','imdb_id','spoken_languages_parsed']].explode('spoken_languages_parsed')
spoken_language_explode.head()

# %%
import matplotlib.pyplot as plt 
plt.hist([movie_metadata['vote_count'][movie_metadata['vote_count'] < 1000]], bins = 5)
plt.title('Distribution of Vote Count')
plt.xlabel('Vote Count')
plt.ylabel('Number of Movies')
plt.show()



total = len(movie_metadata)
filtered = len(movie_metadata[movie_metadata['vote_count'] >= 50])
print(f"Total number of movies: {total}")
print(f"Movies with vote_count >= 50: {filtered}")
print(f"Filtered out: {total - filtered} movies")


# therefore, we can't use the vote average column.
# Out:
# Total number of movies: 45466
# Movies with vote_count >= 50: 9151
# Filtered out: 36315 movies

# %%
keywords_details = pd.json_normalize(keywords_explode['keywords_parsed'])
keywords_details

cast_explode = credits[['id', 'genres_parsed']].explode('genres_parsed')
cast_explode.head()

# %%
# fact table is the links table.

# %%
# step1 ; look at the data first.

import pandas as pd
# return dataframe
credits = pd.read_csv('credits.csv')
keywords = pd.read_csv('keywords.csv')
links = pd.read_csv('links.csv')
movie_metadata = pd.read_csv('movies_metadata.csv')
ratings_small = pd.read_csv('ratings_small.csv')
print(type(ratings_small))
# Out:
# /var/folders/rt/2qm8vc4d2z5429h4tm7j7pkr0000gn/T/ipykernel_1082/2927316014.py:8: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie_metadata = pd.read_csv('movies_metadata.csv')
# <class 'pandas.core.frame.DataFrame'>

# %%
for name, df in [
    ('credits', credits),
    ('keywords', keywords),
    ('links', links),
    ('movie_metadata', movie_metadata),
    ('ratings_small', ratings_small)
]:

    print(f'{name} columns: {df.columns.tolist()}')
# Out:
# credits columns: ['cast', 'crew', 'id']
# keywords columns: ['id', 'keywords']
# links columns: ['movieId', 'imdbId', 'tmdbId']
# movie_metadata columns: ['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count']
# ratings_small columns: ['userId', 'movieId', 'rating', 'timestamp']

# %%
tables = {
    'movie_metadata':   movie_metadata,
    'links':    links,
    'ratings_small':  ratings_small,
    'credits':  credits
}

for table_name, df in tables.items():
    print(f"\n{table_name}:")
    print(f"  columns: {df.columns.tolist()}")
    print(f"  rows: {len(df)}")
    
    id_cols = [col for col in df.columns if 'id' in col.lower()]
    print(f"  id columns: {id_cols}")

# %%
import pandas as pd

movies = pd.read_csv('movies_metadata.csv')


print(movies.columns.tolist())


print(movies['id'].nunique(), len(movies))  


print(ratings_small['movieId'].nunique(), len(ratings_small))
